# %%
from PIL import Image
import requests
from StringIO import StringIO
from IPython.display import Image
from IPython.core.display import HTML
import urllib, json
import pandas as pd
from matplotlib.pyplot import imshow
import matplotlib.image as mpimg
import numpy as np
import random
import os
import matplotlib.pyplot as plt
# %matplotlib inline

#API Key for Google Street View
key = 'AIzaSyDKJ5ka5dSlnFWNQcqedRZax1rKssvn1GA'
#API Key for Geocoding
address_key = 'AIzaSyAoVCmYCVFg-gDkaLhtarYmAs0vzfjdAIk'

#Import postcodes csv
#postcodes = pd.read_csv('/home/sam/Documents/StreetView/LSOA_raw_data/ONS_Postcode_Directory_Latest_Centroids.csv')
postcodes = pd.read_csv('/home/sam/Documents/StreetView/LSOA_raw_data/unique_London_postcodes.csv')

#List of lsoas and associated postcodes
lsoas_postcodes = postcodes[['lsoa01', 'pcd']]

#Example LSOA Lists
# EastDevon = ['E01019886', 'E01019887', 'E01019888', 'E01019889', 'E01019890']
# Kensington = ['E01002812', 'E01002813', 'E01002814', 'E01002815']
# Exeter = ['E01020048']
#Select_LSOAs = ['E01000001', 'E01000002']
Random_London_LSOAs = list(lsoas_postcodes.lsoa01.sample(n = 30))

#LSOA list to download
LSOAs = Random_London_LSOAs

#Image size to download
size = str(640)

# def download_random_streetview():
#     #Generate random lat and lon coordinates around the postcode centroid
#     lat_rand = lat + (random.uniform(-0.0005, 0.0005))
#     lon_rand = lon + (random.uniform(-0.0005, 0.0005))

#     #Query Google StreetView with the random coordinates
#     url = 'https://maps.googleapis.com/maps/api/streetview?location='+\
#     str(lat_rand) + ',' + str(lon_rand) + '&fov=60' + '&size=' + size + 'x' + size + '&key=' + key

#     #Execute API query, saving photo
#     urllib.urlretrieve(url, LSOA_directory + file_name)
#     #Update photo dataframe with new picture information
#     photos = photos.append(pd.DataFrame(
#         [[lat_rand, lon_rand, LSOA_directory+file_name, postcode, LSOA]],
#         columns=['lat', 'lon', 'file_dir', 'postcode', 'LSOA']))

# %%
#Parent Directory for all image downloads
file_directory = '/home/sam/Documents/StreetView/LSOA_downloads/'

#CSV for photo data (directory, geocordinates, postcode etc.)
photo_csv_dir = '/home/sam/Documents/StreetView/LSOA_downloads/photos.csv'


for LSOA in LSOAs:
    
    LSOA_count = 0
    
    if os.path.exists(photo_csv_dir):
        photos = pd.read_csv(photo_csv_dir)
    else:
        photos = pd.DataFrame(columns=['lat', 'lon', 'file_dir', 'postcode', 'LSOA'])
  
    print LSOA
    #Extract given postcodes for each LSOA
    LSOA_postcodes = lsoas_postcodes[lsoas_postcodes.lsoa01 == LSOA].pcd

    #Set directory for images to go to based on LSOA
    LSOA_directory = file_directory + LSOA +'/'

    #Creates LSOA directory if it doesn't already exist
    if not os.path.exists(LSOA_directory):
        os.makedirs(LSOA_directory)    
    
    for postcode in LSOA_postcodes:
        
        print (postcode + ' photos downloading.') 
        
        #Retrieve lat,lon centroids for each postcode
        lat = postcodes[postcodes.pcd == postcode].Y.values[0]
        lon = postcodes[postcodes.pcd == postcode].X.values[0]

        for image_number in range(number_images_per_postcode):

            #Generate filename for queried image
            file_name = str(postcode) + '_' + str(image_number) + '.jpg'
            
            #Check if files are already downloaded for given postcode
            try:
                if not os.path.exists(LSOA_directory + file_name):
                    #Generate random lat and lon coordinates around the postcode centroid
                    lat_rand = lat + (random.uniform(-0.0005, 0.0005))
                    lon_rand = lon + (random.uniform(-0.0005, 0.0005))

                    #Query Google StreetView with the random coordinates
                    url = 'https://maps.googleapis.com/maps/api/streetview?location='+\
                    str(lat_rand) + ',' + str(lon_rand) + '&fov=60' + '&size=' + size + 'x' + size + '&key=' + key

                    #Execute API query, saving photo
                    urllib.urlretrieve(url, LSOA_directory + file_name)
                    #Update photo dataframe with new picture information
                    photos = photos.append(pd.DataFrame(
                    [[lat_rand, lon_rand, file_name, postcode, LSOA]],
                    columns=['lat', 'lon', 'file_dir', 'postcode', 'LSOA']))
                    
                    LSOA_count += 1
                
            except:
                pass
            
    #Write updated photos csv
    photos.to_csv(file_directory + 'photos.csv', index= False)
    print ('LSOA number ' + LSOA + ' written to csv')
    print (str(LSOA_count) + ' photos downloaded.')
# Out:
# E01003692
# IG1 3JL photos downloading.
# IG1 3JN photos downloading.
# IG1 3JR photos downloading.
# IG1 3NU photos downloading.
# IG1 3NZ photos downloading.
# IG1 3PA photos downloading.
# IG1 3PF photos downloading.
# IG1 3QH photos downloading.
# IG1 3QL photos downloading.
# IG1 3QN photos downloading.
# IG1 3QP photos downloading.
# IG1 3QR photos downloading.
# IG1 3QT photos downloading.
# IG1 3QW photos downloading.
# IG1 3QY photos downloading.
# IG1 3RF photos downloading.
# IG1 3RJ photos downloading.
# IG1 4NU photos downloading.
# IG1 4QE photos downloading.
# IG1 4UB photos downloading.
# IG1 4UF photos downloading.
# IG1 4UG photos downloading.
# IG1 4UH photos downloading.
# IG1 4UL photos downloading.
# IG1 4UN photos downloading.
# IG1 4UQ photos downloading.
# IG1 4UR photos downloading.
# LSOA number E01003692 written to csv
# 270 photos downloaded.
# E01004487
# SW129HW photos downloading.
# SW129JT photos downloading.
# SW178AH photos downloading.
# ...
